# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Colab Notebooks/Machine Learning Foundation Course by Coursera/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Machine Learning Foundation Course by Coursera

# %%
# !pip install turicreate
import turicreate
# Out:
# ...
#      |████████████████████████████████| 92.0 MB 14 kB/s
# ...
#      |████████████████████████████████| 3.5 MB 39.2 MB/s
# ...
#      |████████████████████████████████| 86.4 MB 78 kB/s
# ...
#      |████████████████████████████████| 3.6 MB 39.9 MB/s
# ...
#      |████████████████████████████████| 322 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 18.3 MB 449 kB/s
# ...
#      |████████████████████████████████| 50 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 38.5 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 50.5 MB/s
# ...
#      |████████████████████████████████| 449 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 1.2 MB/s
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=a88b0d8511ca25702230150f71e6158e1d977eb35330cbd49f9f4ff2c5e77b9d
#   Stored in directory: /root/.cache/pip/wheels/b2/7f/f6/f180315b584f00445045ff1699b550fa895d09471337ce21c6
# ...

# %%
sf = turicreate.SFrame('people-example.csv')
# Out:
# Finished parsing file /content/gdrive/MyDrive/Colab Notebooks/Machine Learning Foundation Course by Coursera/people-example.csv
# Parsing completed. Parsed 7 lines in 0.032427 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/gdrive/MyDrive/Colab Notebooks/Machine Learning Foundation Course by Coursera/people-example.csv
# Parsing completed. Parsed 7 lines in 0.014686 secs.

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.head()
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.show()
# Out:
# Materializing SFrame
# ...
