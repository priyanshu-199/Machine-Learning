# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Colab Notebooks/Logistic Regression/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Logistic Regression

# %%
import pandas as pd
titanic=pd.read_csv('gender_submission.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.scatter(titanic.PassengerId,titanic.Survived,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=(titanic[['PassengerId']],titanic.Survived,test_size=0.1)
# Out:
#   File "<ipython-input-20-f66dd7f55532>", line 1
#     x_train, x_test, y_train, y_test=(titanic[['PassengerId']],titanic.Survived,test_size=0.1)
#                                                                                          ^
# SyntaxError: invalid syntax
